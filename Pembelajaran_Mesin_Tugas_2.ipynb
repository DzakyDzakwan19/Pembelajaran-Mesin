# %% [markdown]
# <a href="https://colab.research.google.com/github/DzakyDzakwan19/Pembelajaran-Mesin/blob/main/Pembelajaran_Mesin_Tugas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset = '/content/Google.csv'
data = pd.read_csv(dataset)
data
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    49.813290    51.835709    47.800831    49.982655
# 1     2004-08-20    50.316402    54.336334    50.062355    53.952770
# 2     2004-08-23    55.168217    56.528118    54.321388    54.495735
# 3     2004-08-24    55.412300    55.591629    51.591621    52.239197
# 4     2004-08-25    52.284027    53.798351    51.746044    52.802086
# ...          ...          ...          ...          ...          ...
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close    Volume
# 0       49.982655  44871361
# 1       53.952770  22942874
# 2       54.495735  18342897
# ...

# %%
data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
print(data.dtypes)
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#             Date         Open         High          Low    Adj Close    Volume
# 0     2004-08-19    49.813290    51.835709    47.800831    49.982655  44871361
# 1     2004-08-20    50.316402    54.336334    50.062355    53.952770  22942874
# 2     2004-08-23    55.168217    56.528118    54.321388    54.495735  18342897
# 3     2004-08-24    55.412300    55.591629    51.591621    52.239197  15319808
# 4     2004-08-25    52.284027    53.798351    51.746044    52.802086   9232276
# ...          ...          ...          ...          ...          ...       ...
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098   1164100
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029   1078800
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020   1399100
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912   1459600
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010   1878100
#
# [4471 rows x 6 columns]

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4471.000000  4471.000000  4471.000000  4471.000000  4471.000000
# mean    705.987766   712.902254   698.921464   706.024620   706.024620
# std     668.889418   675.581259   662.083510   668.843248   668.843248
# min      49.409801    50.680038    47.800831    49.818268    49.818268
# 25%     248.256973   251.183502   245.313003   248.237045   248.237045
# 50%     436.992035   439.273499   434.421692   436.897400   436.897400
# 75%    1022.239990  1034.835022  1012.175018  1022.334992  1022.334992
# max    3037.270020  3042.000000  2997.750000  3014.179932  3014.179932
#
#              Volume
# count  4.471000e+03
# mean   6.347083e+06
# std    7.751824e+06
# min    7.922000e+03
# 25%    1.538250e+06
# 50%    3.646015e+06
# 75%    7.981003e+06
# max    8.254163e+07

# %%
data.loc[:,"Open":].corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999915  0.999896  0.999799   0.999799 -0.456140
# High       0.999915  1.000000  0.999871  0.999898   0.999898 -0.455170
# Low        0.999896  0.999871  1.000000  0.999913   0.999913 -0.457679
# Close      0.999799  0.999898  0.999913  1.000000   1.000000 -0.456599
# Adj Close  0.999799  0.999898  0.999913  1.000000   1.000000 -0.456599
# Volume    -0.456140 -0.455170 -0.457679 -0.456599  -0.456599  1.000000

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Open', y='Volume', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# WITH API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s "Google"
# Out:
# ...
# ref                                                title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# google/google-landmarks-dataset                    Google-Landmarks Dataset                            1KB  2022-07-15 16:45:11           9531        646  0.7647059
# google/tinyquickdraw                               QuickDraw Sketches                                 11GB  2018-04-18 19:38:04           3909        385  0.8125
# niyamatalmass/google-job-skills                    Google Job Skills                                 407KB  2018-01-07 06:01:20          12182        325  1.0
# ...

# %%
# !kaggle datasets download google/google-landmarks-dataset
# Out:
# google-landmarks-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/google-landmarks-dataset
# Out:
# Archive:  /content/google-landmarks-dataset.zip
# replace boxes_split1.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
#   inflating: boxes_split1.csv
# replace boxes_split2.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: boxes_split2.csv
# replace index.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: index.csv
# replace recognition_solution.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: recognition_solution.csv
# replace retrieval_solution.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: retrieval_solution.csv
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: test.csv
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: train.csv

# %%
pd.read_csv('/content/Google.csv')
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    49.813290    51.835709    47.800831    49.982655
# 1     2004-08-20    50.316402    54.336334    50.062355    53.952770
# 2     2004-08-23    55.168217    56.528118    54.321388    54.495735
# 3     2004-08-24    55.412300    55.591629    51.591621    52.239197
# 4     2004-08-25    52.284027    53.798351    51.746044    52.802086
# ...          ...          ...          ...          ...          ...
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close    Volume
# 0       49.982655  44871361
# 1       53.952770  22942874
# 2       54.495735  18342897
# ...
